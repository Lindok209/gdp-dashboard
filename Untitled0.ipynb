# %% [markdown]
# <a href="https://colab.research.google.com/github/Lindok209/gdp-dashboard/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Tell me about this dataset.
#
# Here is all the data you need:
# "adult.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the "adult.csv" dataset.

# %% [markdown]
# **Reasoning**:
# Load the dataset and display its first few rows and shape to verify successful loading.

# %%
# !pip install aif360
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 kB 3.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Input

# %%
import pandas as pd

try:
    df = pd.read_csv('adult.csv')
    display(df.head())
    print(df.shape)
except FileNotFoundError:
    print("Error: 'adult.csv' not found.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded dataset to understand its characteristics.

# %% [markdown]
# **Reasoning**:
# I need to explore the dataset's characteristics, including data types, shape, unique values, and potential missing values or inconsistencies.

# %%
# Data Types and Shape
print("Data Types:\n", df.dtypes)
print("\nShape:\n", df.shape)

# Unique Values and Distributions
for col in df.columns:
    print(f"\nColumn: {col}")
    print(f"  Unique Values: {df[col].nunique()}")
    if df[col].nunique() < 20:  # Print value counts for categorical features with fewer unique values
        print(f"  Value Counts:\n{df[col].value_counts()}")
    else:
        print(f"  Descriptive Statistics:\n{df[col].describe()}")

# Missing Values
for col in df.columns:
    if df[col].dtype == 'object':
      missing_count = df[col].isin(['?']).sum()
      if missing_count > 0:
          print(f"\nColumn '{col}' has {missing_count} missing values (represented as '?').")
          print(f"  Percentage of missing values: {missing_count / len(df) * 100:.2f}%")
# Out:
# Data Types:
#  age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object
#
# Shape:
#  (48842, 15)
#
# Column: age
#   Unique Values: 74
#   Descriptive Statistics:
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64
#
# Column: workclass
#   Unique Values: 9
#   Value Counts:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# ...

# %% [markdown]
# **Reasoning**:
# The previous code block's output was truncated. I need to complete the execution and analysis of the data.  I will also check for missing values in numerical columns which were not done in the previous step.

# %%
# Continue printing the descriptive statistics from the previous code block
for col in df.columns:
    print(f"\nColumn: {col}")
    print(f"  Unique Values: {df[col].nunique()}")
    if df[col].nunique() < 20:  # Print value counts for categorical features with fewer unique values
        print(f"  Value Counts:\n{df[col].value_counts()}")
    else:
        print(f"  Descriptive Statistics:\n{df[col].describe()}")

# Check for missing values in numerical columns (represented by other values than '?')
for col in df.columns:
    if df[col].dtype != 'object':
        missing_count = df[col].isnull().sum()
        if missing_count > 0:
            print(f"\nColumn '{col}' has {missing_count} missing values.")
            print(f"  Percentage of missing values: {missing_count / len(df) * 100:.2f}%")

# Analyze 'income' column
print(f"\nColumn: income")
print(f"  Value Counts:\n{df['income'].value_counts()}")
# Out:
# Column: age
#   Unique Values: 74
#   Descriptive Statistics:
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64
#
# Column: workclass
#   Unique Values: 9
#   Value Counts:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64
#
# Column: fnlwgt
#   Unique Values: 28523
#   Descriptive Statistics:
# count    4.884200e+04
# mean     1.896641e+05
# std      1.056040e+05
# min      1.228500e+04
# 25%      1.175505e+05
# 50%      1.781445e+05
# 75%      2.376420e+05
# max      1.490400e+06
# Name: fnlwgt, dtype: float64
#
# Column: education
#   Unique Values: 16
#   Value Counts:
# ...

# %% [markdown]
# ## Data analysis
#
# ### Subtask:
# Analyze the dataset to gain insights into the data.

# %% [markdown]
# **Reasoning**:
# Calculate descriptive statistics for numerical features, analyze frequency distribution of categorical features, investigate correlations between numerical features, and examine the relationship between numerical and target variable.

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize key features and relationships within the dataset.

# %% [markdown]
# **Reasoning**:
# Generate visualizations to understand the data distribution and relationships between features, as per the subtask instructions.

# %% [markdown]
# **Reasoning**:
# The previous code block generated some warnings about the use of `palette` in `seaborn.boxplot`.  I will correct the code to remove these warnings, and make some minor adjustments to the visualization to improve the clarity.  The figures were not displayed properly so I'll also make sure the plots are displayed.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# There were no explicit questions asked in the task. However, the overall goal was to understand the "adult.csv" dataset through loading, exploration, analysis, and visualization.
#
# ### Data Analysis Key Findings
# * **Missing Data:** The `workclass`, `occupation`, and `native.country` columns contain missing values represented by "?".
# * **Income Imbalance:** The target variable, `income`, is imbalanced, with approximately 76% of individuals earning "<=50K" and 24% earning ">50K".
# * **Numerical Feature Distributions:**  Histograms and box plots revealed the distributions of numerical features like `age`, `fnlwgt`, `education.num`, `capital.gain`, `capital.loss`, and `hours.per.week`, showing varying degrees of skewness and potential outliers.  For example, `capital.gain` and `capital.loss` appear highly skewed.
# * **Relationships with Income:**  Visualizations and descriptive statistics highlighted relationships between numerical and categorical features and income levels. For example,  the analysis showed how the distribution of `hours.per.week` differs between income groups.  The proportion of individuals in different `education` and `marital.status` categories also varies significantly across income levels.
#
#
# ### Insights or Next Steps
# * **Handle Missing Data:** Address the missing values in the `workclass`, `occupation`, and `native.country` columns using appropriate imputation techniques or removal strategies.
# * **Mitigate Class Imbalance:** Explore techniques like oversampling the minority class, undersampling the majority class, or using cost-sensitive learning algorithms to address the income class imbalance during model training.
